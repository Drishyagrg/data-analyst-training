# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Country': [11, 10],
    'Year': [2014, 2015],
    'Status': [1, 1],   
    'Adult Mortality': [250, 180],
    'Alcohol': [4.5, 3.2],
    'Hepatitis B': [85, 90],
    'Measles ': [10, 0],
    ' BMI ': [22.1, 24.3],
    'under-five deaths ': [45, 30],
    'Polio': [88, 92],
    'Total expenditure': [6.5, 7.1],
    'Diphtheria ': [89, 93],
    ' HIV/AIDS': [0.3, 0.1],
    'GDP': [1200, 1500],
    'Population': [5000000, 7000000],
    ' thinness  1-19 years': [5.2, 4.8],
    'Schooling': [10.5, 12.3]
})

# %%
df
# Out:
#    Country  Year  Status  Adult Mortality  Alcohol  Hepatitis B  Measles   \
# 0       11  2014       1              250      4.5           85        10
# 1       10  2015       1              180      3.2           90         0
#
#     BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# 0   22.1                  45     88                6.5           89
# 1   24.3                  30     92                7.1           93
#
#     HIV/AIDS   GDP  Population   thinness  1-19 years  Schooling
# 0        0.3  1200     5000000                    5.2       10.5
# 1        0.1  1500     7000000                    4.8       12.3

# %%
import joblib
model= joblib.load('linear.joblib')

# %%
prediction= model.predict(df)
prediction
# Out:
# array([67.61475966, 71.2585765 ])
